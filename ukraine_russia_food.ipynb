# %% [markdown]
# <a href="https://colab.research.google.com/github/jloreto9/datasciencecoder/blob/main/ukraine_russia_food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os, sys
from matplotlib import pyplot as plt

import plotly.express as px

# %% [markdown]
# # Montamos COLAB sobre la ruta de Google Drive
#
# ## EXPLORANDO y VISUALIZANDO datos

# %%
# montando Colab sobre la ruta dentro de Google Drive.
from google.colab import drive
drive.mount('/content/drive')
#drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Establezco el Path en Google Drive

# %%
path = '/content/drive/My Drive/Datasets/'
import sys
sys.path.insert(0,path)

# %% [markdown]
# # Importo el directorio en la carpera de Drive mencionada

# %%
import os
os.listdir(path)
# Out:
# ['ukraine-russia-food.csv', 'World_Airports.csv']

# %% [markdown]
# # Formulo la variable World_Airports_df como el dataset a evaluar

# %%
ukraine_russia_food_df = pd.read_csv(path+"ukraine-russia-food.csv")

ukraine_russia_food_df.head(15)
# Out:
#     Domestic wheat supply  Wheat exports  Wheat imports  Wheat stocks  \
# 0                 6209000            NaN       206145.0        182000
# 1                 6011000            NaN       220428.0       -402000
# 2                 6186000            NaN       204801.0        497000
# 3                 6639000            NaN       222974.0        343000
# 4                 6586000            0.0        78730.0        250000
# 5                 6760000            0.0       176539.0       -180000
# 6                 6880000            0.0       258473.0        446000
# 7                 7151000            NaN       728124.0        208000
# 8                 7036000            NaN       692468.0         -4000
# 9                 7519000            NaN       431909.0       -104000
# 10               60013000            NaN            NaN      -1013000
# 11               62353000            NaN            NaN       3966000
# ...

# %% [markdown]
# # Cambio el formato de visualizacion de las dos primeras columnas para asi eliminar la notacion cientifica

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Chequeamos de nuevo el dataset

# %%
ukraine_russia_food_df.head(15)
# Out:
#     Domestic wheat supply  Wheat exports  Wheat imports  Wheat stocks  \
# 0                 6209000            NaN      206145.00        182000
# 1                 6011000            NaN      220428.00       -402000
# 2                 6186000            NaN      204801.00        497000
# 3                 6639000            NaN      222974.00        343000
# 4                 6586000           0.00       78730.00        250000
# 5                 6760000           0.00      176539.00       -180000
# 6                 6880000           0.00      258473.00        446000
# 7                 7151000            NaN      728124.00        208000
# 8                 7036000            NaN      692468.00         -4000
# 9                 7519000            NaN      431909.00       -104000
# 10               60013000            NaN            NaN      -1013000
# 11               62353000            NaN            NaN       3966000
# ...

# %%
ukraine_russia_food_df
# Out:
#       Domestic wheat supply  Wheat exports  Wheat imports  Wheat stocks  \
# 0                   6209000            NaN      206145.00        182000
# 1                   6011000            NaN      220428.00       -402000
# 2                   6186000            NaN      204801.00        497000
# 3                   6639000            NaN      222974.00        343000
# 4                   6586000           0.00       78730.00        250000
# ...                     ...            ...            ...           ...
# 1839                 405000        1510.00      231293.00        -16000
# 1840                 348000           0.00      268891.00         34000
# 1841                 292000       16500.00      205760.00        -37000
# 1842                 283000           7.00      276776.00         67000
# 1843                 377000         300.00      124632.00       -165000
#
#       Net wheat imports  Wheat imports (% domestic supply)  \
# ...

# %% [markdown]
# # Ahora veamos que tipo de DataFrame es

# %%
ukraine_russia_food_df.dtypes
# Out:
# Domestic wheat supply                                       int64
# Wheat exports                                             float64
# Wheat imports                                             float64
# Wheat stocks                                                int64
# Net wheat imports                                         float64
#                                                            ...
# Sunflower oil imports from Ukraine (% supply)             float64
# Sunflower oil imports from Russia (% supply)              float64
# Sunflower oil imports from Ukraine + Russia (% supply)    float64
# Entity                                                     object
# Year                                                        int64
# Length: 98, dtype: object

# %%
ukraine_russia_food_df.shape
# Out:
# (1844, 98)
